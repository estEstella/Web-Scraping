# %% [markdown]
# <h1 align="center"> Web Scrapy Project - Crypto Punk! </h1>
# <h2 align="center"> <font size='4'>Chenchen Liu </h2>

# %% [markdown]
# This web scrapy project extracts data from crypto punk website where pixel art images are traded as NFT on Ethereum. Using various punk data including index, type, attribute, ownership, price, transaction frequency, transaction type and transaction date to analyze and predict its market value. Please note 10,000 punks are collected from web scrapy and the project is only for education purpose.

# %% [markdown]
# ## 1. Data Collection

# %%
from bs4 import BeautifulSoup # For HTML parsing
import requests # Website connections
from time import sleep # To prevent overwhelming the server between connections
import pandas as pd # For converting results to a dataframe and bar chart plots
import numpy as np # For data cleaning
import random # To generater random number

# %% [markdown]
# - Get webpage information from cryptopunk website

# %%
def get_page(page_num):
    url = f'https://www.larvalabs.com/cryptopunks/details/{page_num}'
    result = requests.get(url)
    soup = BeautifulSoup(result.content)
    return soup

# %%
#Get attribute of cryptopunk, save data to csv file

index = []
number = []

for page_num in range(0 ,10000):
    soup = get_page(page_num)

    sleep(2) 
        
    for tag in soup.find_all('div', class_='col-md-4')[1:]:
        try:
            number.append(tag.a.get_text())
        except:
            number.append('error')
        index.append(page_num)
        mapped = list(zip(index, number))
        
        if page_num % 1111 == 0:
            pd.DataFrame(mapped, columns=['number', 'attribute']).to_csv(f'attribute_data-{page_num}.csv')

# %%
#cryptopunk main dataframe, save data to csv file

data = []

for page_num in range(0,10000):
    soup = get_page(page_num)
    
    sleep(6) 
    
    # Get the index number of cryptopunk
    try:
        number = soup.find('li',class_='active').text
    except:
        number = 'error'
        
    # Get the character type of cryptopunk   
    try:
        type_ = soup.find('div',class_='col-md-10 col-md-offset-1 col-xs-12').a.text
    except:
        type_ = 'error'
    
    # Get the initial owner of cryptopunk
    try:
        initial_owner = soup.find("tr",{"class":"punk-history-row-claim"}).a.text
    except:
        initial_owner = 'error'
    
    # Get the current owner of cryptopunk
    try:
        current_owner = soup.find_all("div",{"class":"col-md-10 col-md-offset-1"})[1].a.text
    except:
        current_owner = 'error'
    
    # Get the latest transaction type of cryptopunk
    try:
        type_TX = soup.find("table",{"class":"table"}).find_all("tr")[1].find_all("td")[0].text
    except:
        type_TX = 'error'
    
    # Get the initial_market_value of cryptopunk
    try:
        initial_market_value = soup.find("table",{"class":"table"}).find_all("tr")[-2].find_all("td")[3].text
    except:
        initial_market_value = 0
        
    # Get the latest_market_value of cryptopunk 
    try:
        latest_market_value = soup.find("table",{"class":"table"}).find_all("tr")[1].find_all("td")[3].text
    except:
        latest_market_value = 'error'
    
    # Get total number of transactions of cryptopunk
    try:
        transaction_frequency = pd.read_html(requests.get(f'https://www.larvalabs.com/cryptopunks/details/{page_num}').text)[0].shape[0]-1
    except:
        transaction_frequency = 'error'
    
   # Get the initial transaction date of cryptopunk
    try:
        initial_TXD = soup.find("table",{"class":"table"}).find_all("tr")[-2].find_all("td")[4].text
    except:
        initial_TXD = 'error'
        
    # Get the latest transaction date of cryptopunk: 
    try:
        latest_TXD = soup.find("table",{"class":"table"}).find_all("tr")[1].find_all("td")[4].a.text
    except:
        latest_TXD = 'error'
    
    # Combine all the attributes into dictionary
    row = {'number': number, 
           'punk_type': type_, 
           'initial_owner': initial_owner,
           'current_owner': current_owner,
           'transaction_type': type_TX,
           'transaction_frequency': transaction_frequency,
           'initial_market_value': initial_market_value,
           'latest_market_value': latest_market_value,
           'initial_TXD': initial_TXD,
           'latest_TXD' :latest_TXD
          }
    
    data.append(row)
    
    # Save to csv file
    if page_num % 1111 == 0:
        pd.DataFrame(data).to_csv(f'pd_data-{page_num}.csv')

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# 1. Clean crypto punk attribute data

# %%
df1 = pd.read_csv("attribute_data.csv")
df1
# Out:
#        Unnamed: 0  number         attribute
# 0               0       0  Green Eye Shadow
# 1               1       0           Earring
# 2               2       0        Blonde Bob
# 3               3       1             Smile
# 4               4       1            Mohawk
# ...           ...     ...               ...
# 21260       21260    9998   Wild White Hair
# 21261       21261    9998    Black Lipstick
# 21262       21262    9998  Clown Eyes Green
# 21263       21263    9999            Mohawk
# 21264       21264    9999      Nerd Glasses
#
# [21265 rows x 3 columns]

# %%
# remove column 'Unnamed: 0' in df1
df1 = df1.drop(columns=['Unnamed: 0'])

# %%
df1
# Out:
#        number         attribute
# 0           0  Green Eye Shadow
# 1           0           Earring
# 2           0        Blonde Bob
# 3           1             Smile
# 4           1            Mohawk
# ...       ...               ...
# 21260    9998   Wild White Hair
# 21261    9998    Black Lipstick
# 21262    9998  Clown Eyes Green
# 21263    9999            Mohawk
# 21264    9999      Nerd Glasses
#
# [21265 rows x 2 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21265 entries, 0 to 21264
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   number     21265 non-null  int64
#  1   attribute  21265 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 332.4+ KB

# %% [markdown]
# 2. Clean crypto punk main dataframe

# %%
df2 = pd.read_csv('punk_data_UTF8.csv')

# %%
df2.head(20)
# Out:
#     Unnamed: 0  number punk_type initial_owner current_owner transaction_type  \
# 0            0       0    Female      0xc352b5      0xe08c32    Bid Withdrawn
# 1            1       1      Male      0xc352b5      0xb88f61         Transfer
# 2            2       2    Female      0xc352b5      0x897aea         Transfer
# 3            3       3      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 4            4       4      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 5            5       5    Female      0xc352b5   WrappedC?€?              Bid
# 6            6       6      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 7            7       7    Female      0xc352b5      0xc352b5    Bid Withdrawn
# 8            8       8      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 9            9       9      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 10          10      10    Female      0xc352b5      0xc352b5    Bid Withdrawn
# 11          11      11    Female      0xc352b5      0xc352b5          Claimed
# 12          12      12    Female      0xc352b5      0xc352b5    Bid Withdrawn
# 13          13      13    Female      0xc352b5      0xc352b5    Bid Withdrawn
# 14          14      14    Female      0xc352b5   0x7c00c9?€?    Bid Withdrawn
# 15          15      15      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 16          16      16      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 17          17      17      Male      0xc352b5      0xc352b5              Bid
# 18          18      18      Male      0xc352b5      0xc352b5          Claimed
# 19          19      19    Female      0xc352b5      0xc352b5    Bid Withdrawn
#
#     transaction_frequency initial_market_value latest_market_value  \
# 0                      34        0.67?? ($219)      250?? ($1.03M)
# 1                      52         0.20?? ($61)                 NaN
# 2                      25        0.42?? ($117)                 NaN
# 3                      14         0.05?? ($13)      33?? ($11,638)
# 4                      11         0.10?? ($28)     28?? ($109,026)
# 5                      13         0.06?? ($15)    4.20?? ($11,322)
# 6                       6         0.06?? ($15)      10?? ($10,126)
# 7                      11         0.06?? ($15)       1.75?? ($551)
# 8                      18         0.06?? ($15)      30?? ($68,985)
# 9                      30         0.06?? ($15)      36?? ($13,597)
# 10                     10         0.06?? ($15)   25.50?? ($45,336)
# 11                      0                    0                 NaN
# 12                      3         0.05?? ($13)        0.50?? ($65)
# 13                     17         0.05?? ($13)     42?? ($116,917)
# 14                     31         0.05?? ($14)   33.25?? ($64,905)
# 15                     10         0.10?? ($30)  57.50?? ($123,576)
# 16                      2      1.60?? ($3,011)     1.60?? ($3,385)
# 17                      3         <0.01?? ($0)       0.10?? ($222)
# 18                      0                    0                 NaN
# 19                      2        2.30?? ($464)       2.30?? ($470)
#
#    initial_TXD latest_TXD
# 0    23-Jun-17  10-May-21
# 1    24-Jun-17  30-Nov-20
# 2    25-Jun-17  09-Jun-21
# 3    26-Jun-17  04-Oct-20
# 4    25-Jun-17  13-May-21
# 5    26-Jun-17  29-Apr-21
# 6    26-Jun-17  04-Jan-21
# 7    26-Jun-17  26-Jul-20
# 8    26-Jun-17  13-Apr-21
# 9    26-Jun-17  14-Oct-20
# 10   26-Jun-17  21-Mar-21
# 11   23-Jun-17  23-Jun-17
# 12   26-Jun-17  02-Jan-20
# 13   26-Jun-17  07-Jun-21
# 14   25-Jun-17  20-Feb-21
# 15   24-Jun-17  18-Apr-21
# 16   31-Mar-21  05-Apr-21
# 17   10-Mar-20  20-Apr-21
# 18   23-Jun-17  23-Jun-17
# 19   22-May-20  26-May-20

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             10000 non-null  int64
#  1   number                 10000 non-null  int64
#  2   punk_type              10000 non-null  object
#  3   initial_owner          10000 non-null  object
#  4   current_owner          10000 non-null  object
#  5   transaction_type       10000 non-null  object
#  6   transaction_frequency  10000 non-null  int64
#  7   initial_market_value   7683 non-null   object
#  8   latest_market_value    5541 non-null   object
#  9   initial_TXD            10000 non-null  object
#  10  latest_TXD             10000 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 859.5+ KB

# %%
# remove column 'Unnamed: 0' in df1
df2 = df2.drop(columns=['Unnamed: 0'])

# %%
# convert initial_TXD and latest_TXD to datetime data type
df2['initial_TXD'] =  pd.to_datetime(df2['initial_TXD'], format = '%d-%b-%y')
df2['latest_TXD'] =  pd.to_datetime(df2['latest_TXD'], format = '%d-%b-%y')

# %%
# Add year of initial_TXD and latest_TXD in tow new columns
df2['initial_TXY'] = df2['initial_TXD'].dt.year
df2['latest_TXY'] = df2['latest_TXD'].dt.year

# %%
#convert initial_market_value to US dollar

df2['initial_market_value'] = df2['initial_market_value'].str.replace('$', '').str.findall('\((.*)\)').str.get(0) \
                                                         .str.replace(',','').str.replace('<','').str.replace('Y','').fillna(0) 

df2['initial_market_value'] = (df2['initial_market_value'].replace(r'[ZMP]+$', '', regex=True).astype(float) * \
                               df2['initial_market_value'].str.extract(r'[\d\.]+([ZMP]+)', expand=False)
                               .fillna(1)
                               .replace(['Z','M', 'P'], [10**15, 10**6, 10**15]).astype(float))

#convert latest_market_value to US dollar

df2['latest_market_value'] = df2['latest_market_value'].str.replace('$', '').str.findall('\((.*)\)').str.get(0) \
                                                       .str.replace(',','').str.replace('<','').str.replace('Y','').fillna(0) 

df2['latest_market_value']= (df2['latest_market_value'].replace(r'[ZMB]+$', '', regex=True).astype(float) * \
                             df2['latest_market_value'].str.extract(r'[\d\.]+([ZMB]+)', expand=False)
                             .fillna(1)
                             .replace(['Z','M', 'B'], [10**15, 10**6, 10**9]).astype(float))

# %%
#convert transaction_frequency to int
df2['transaction_frequency'] = pd.to_numeric(df2['transaction_frequency'], errors='coerce').convert_dtypes()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   number                 10000 non-null  int64
#  1   punk_type              10000 non-null  object
#  2   initial_owner          10000 non-null  object
#  3   current_owner          10000 non-null  object
#  4   transaction_type       10000 non-null  object
#  5   transaction_frequency  10000 non-null  Int64
#  6   initial_market_value   10000 non-null  float64
#  7   latest_market_value    10000 non-null  float64
#  8   initial_TXD            10000 non-null  datetime64[ns]
#  9   latest_TXD             10000 non-null  datetime64[ns]
#  10  initial_TXY            10000 non-null  int64
#  11  latest_TXY             10000 non-null  int64
# dtypes: Int64(1), datetime64[ns](2), float64(2), int64(3), object(4)
# memory usage: 947.4+ KB

# %%
df2
# Out:
#       number punk_type initial_owner current_owner transaction_type  \
# 0          0    Female      0xc352b5      0xe08c32    Bid Withdrawn
# 1          1      Male      0xc352b5      0xb88f61         Transfer
# 2          2    Female      0xc352b5      0x897aea         Transfer
# 3          3      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 4          4      Male      0xc352b5      0xc352b5    Bid Withdrawn
# ...      ...       ...           ...           ...              ...
# 9995    9995    Female   Punkofth?€?      0x758353    Bid Withdrawn
# 9996    9996      Male      0xa9bfa9      0xa9bfa9    Bid Withdrawn
# 9997    9997    Zombie        TJ2010      0x279679          Offered
# 9998    9998    Female   cyberpun?€?      0xcfd9cc  Offer Withdrawn
# 9999    9999    Female      0x7e2d1c   punk9999?€?              Bid
#
#       transaction_frequency  initial_market_value  latest_market_value  \
# 0                        34                 219.0            1030000.0
# 1                        52                  61.0                  0.0
# 2                        25                 117.0                  0.0
# 3                        14                  13.0              11638.0
# 4                        11                  28.0             109026.0
# ...                     ...                   ...                  ...
# 9995                      6                  16.0              63960.0
# 9996                      4                  11.0               1338.0
# 9997                     36                  46.0            1480000.0
# 9998                      9                4292.0                  0.0
# 9999                     49                  50.0                960.0
#
#      initial_TXD latest_TXD  initial_TXY  latest_TXY
# 0     2017-06-23 2021-05-10         2017        2021
# 1     2017-06-24 2020-11-30         2017        2020
# 2     2017-06-25 2021-06-09         2017        2021
# 3     2017-06-26 2020-10-04         2017        2020
# 4     2017-06-25 2021-05-13         2017        2021
# ...          ...        ...          ...         ...
# 9995  2017-06-28 2021-04-20         2017        2021
# 9996  2017-08-04 2021-01-20         2017        2021
# 9997  2017-06-24 2021-05-17         2017        2021
# 9998  2017-06-27 2021-05-04         2017        2021
# 9999  2017-06-23 2021-05-12         2017        2021
#
# [10000 rows x 12 columns]

# %%
#check extreme value in initial_market_value
df2[df2['initial_market_value']>10000000]
# Out:
#       number punk_type initial_owner current_owner transaction_type  \
# 4342    4342      Male      0x2bcbbd   Tschuuul?€?             Sold
# 4714    4714      Male   tonyherr?€?   tonyherr?€?          Offered
# 4722    4722    Female   tonyherr?€?   tonyherr?€?          Offered
# 4727    4727      Male   tonyherr?€?   tonyherr?€?          Offered
# 6141    6141    Female      0x58164b      0x717403              Bid
# 6748    6748      Male      0x0873fc      0x6abc0b    Bid Withdrawn
#
#       transaction_frequency  initial_market_value  latest_market_value  \
# 4342                      5          3.137773e+08         9.100000e+01
# 4714                      1          3.927814e+38         3.927814e+38
# 4722                      1          3.377685e+38         3.377685e+38
# 4727                      1          2.875873e+38         2.875873e+38
# 6141                      4          2.741000e+16         6.400000e+01
# 6748                     47          2.688000e+17         6.072000e+03
#
#      initial_TXD latest_TXD  initial_TXY  latest_TXY
# 4342  2017-11-03 2019-04-08         2017        2019
# 4714  2021-05-03 2021-05-03         2021        2021
# 4722  2021-05-01 2021-05-01         2021        2021
# 4727  2021-06-08 2021-06-08         2021        2021
# 6141  2017-06-24 2020-12-18         2017        2020
# 6748  2017-07-06 2021-06-13         2017        2021

# %%
#check extreme value in latest_market_value
df2[df2['latest_market_value']>10000000]
# Out:
#       number punk_type      initial_owner current_owner transaction_type  \
# 547      547    Female           0xc352b5   Tschuuul?€?          Offered
# 950      950      Male           0xc352b5   Tschuuul?€?          Offered
# 1357    1357    Female        Punkofth?€?      0x758353          Offered
# 1477    1477    Female        shilpixe?€?   Tschuuul?€?          Offered
# 1750    1750    Female           0x00bd9f      0x671f71          Offered
# 2106    2106      Male           0x00d7c9      0x592234          Offered
# 2204    2204    Female           0xcbd482      0x577ebc          Offered
# 2294    2294      Male           0x365e35      0xff0bd4          Offered
# 2345    2345      Male        Punkofth?€?      0x758353          Offered
# 2468    2468      Male        Punkofth?€?      0x758353          Offered
# 4426    4426      Male           0x2fdacd   zeroexze?€?          Offered
# 4557    4557      Male            doh.eth       doh.eth          Offered
# 4567    4567      Male        Punkofth?€?      0x758353          Offered
# 4713    4713      Male        tonyherr?€?   tonyherr?€?          Offered
# 19       7    Clown Eyes Blue    Female      0xc352b5      0xc352b5
#
#    transaction_type  transaction_frequency  initial_market_value  \
# 0     Bid Withdrawn                     34                 219.0
# 1     Bid Withdrawn                     34                 219.0
# 2     Bid Withdrawn                     34                 219.0
# 3          Transfer                     52                  61.0
# 4          Transfer                     52                  61.0
# 5          Transfer                     25                 117.0
# 6     Bid Withdrawn                     14                  13.0
# 7     Bid Withdrawn                     14                  13.0
# 8     Bid Withdrawn                     14                  13.0
# 9     Bid Withdrawn                     11                  28.0
# 10    Bid Withdrawn                     11                  28.0
# 11    Bid Withdrawn                     11                  28.0
# 12    Bid Withdrawn                     11                  28.0
# 13              Bid                     13                  15.0
# 14              Bid                     13                  15.0
# 15              Bid                     13                  15.0
# 16    Bid Withdrawn                      6                  15.0
# 17    Bid Withdrawn                     11                  15.0
# 18    Bid Withdrawn                     11                  15.0
# 19    Bid Withdrawn                     11                  15.0
#
#     latest_market_value initial_TXD latest_TXD  initial_TXY  latest_TXY
# 0             1030000.0  2017-06-23 2021-05-10         2017        2021
# 1             1030000.0  2017-06-23 2021-05-10         2017        2021
# 2             1030000.0  2017-06-23 2021-05-10         2017        2021
# 3                   0.0  2017-06-24 2020-11-30         2017        2020
# 4                   0.0  2017-06-24 2020-11-30         2017        2020
# 5                   0.0  2017-06-25 2021-06-09         2017        2021
# 6               11638.0  2017-06-26 2020-10-04         2017        2020
# 7               11638.0  2017-06-26 2020-10-04         2017        2020
# 8               11638.0  2017-06-26 2020-10-04         2017        2020
# 9              109026.0  2017-06-25 2021-05-13         2017        2021
# 10             109026.0  2017-06-25 2021-05-13         2017        2021
# 11             109026.0  2017-06-25 2021-05-13         2017        2021
# 12             109026.0  2017-06-25 2021-05-13         2017        2021
# 13              11322.0  2017-06-26 2021-04-29         2017        2021
# 14              11322.0  2017-06-26 2021-04-29         2017        2021
# 15              11322.0  2017-06-26 2021-04-29         2017        2021
# 16              10126.0  2017-06-26 2021-01-04         2017        2021
# 17                551.0  2017-06-26 2020-07-26         2017        2020
# 18                551.0  2017-06-26 2020-07-26         2017        2020
# 19                551.0  2017-06-26 2020-07-26         2017        2020

# %% [markdown]
# ## 3. Data Visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.offline as py
import plotly.graph_objs as go 
import plotly.express as px

py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# - Estimated average annual investment return rate

# %%
#filter valid initial market value, latest market value adn transaction year

df_irr = df2[(df2['initial_market_value'] > 1) & (df2['initial_market_value'] < 10000000) & \
             (df2['latest_market_value'] > 1) & (df2['latest_market_value'] < 10000000) & \
             (df2['initial_TXY'] != df2['latest_TXY'])]
df_irr
# Out:
#       number punk_type initial_owner current_owner transaction_type  \
# 0          0    Female      0xc352b5      0xe08c32    Bid Withdrawn
# 3          3      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 4          4      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 5          5    Female      0xc352b5   WrappedC?€?              Bid
# 6          6      Male      0xc352b5      0xc352b5    Bid Withdrawn
# ...      ...       ...           ...           ...              ...
# 9992    9992      Male      0xba7ccc      0xcffc33    Bid Withdrawn
# 9995    9995    Female   Punkofth?€?      0x758353    Bid Withdrawn
# 9996    9996      Male      0xa9bfa9      0xa9bfa9    Bid Withdrawn
# 9997    9997    Zombie        TJ2010      0x279679          Offered
# 9999    9999    Female      0x7e2d1c   punk9999?€?              Bid
#
#       transaction_frequency  initial_market_value  latest_market_value  \
# 0                        34                 219.0            1030000.0
# 3                        14                  13.0              11638.0
# 4                        11                  28.0             109026.0
# 5                        13                  15.0              11322.0
# 6                         6                  15.0              10126.0
# ...                     ...                   ...                  ...
# 9992                      5                  16.0              82439.0
# 9995                      6                  16.0              63960.0
# 9996                      4                  11.0               1338.0
# 9997                     36                  46.0            1480000.0
# 9999                     49                  50.0                960.0
#
#      initial_TXD latest_TXD  initial_TXY  latest_TXY
# 0     2017-06-23 2021-05-10         2017        2021
# 3     2017-06-26 2020-10-04         2017        2020
# 4     2017-06-25 2021-05-13         2017        2021
# 5     2017-06-26 2021-04-29         2017        2021
# 6     2017-06-26 2021-01-04         2017        2021
# ...          ...        ...          ...         ...
# 9992  2017-06-28 2021-05-05         2017        2021
# 9995  2017-06-28 2021-04-20         2017        2021
# 9996  2017-08-04 2021-01-20         2017        2021
# 9997  2017-06-24 2021-05-17         2017        2021
# 9999  2017-06-23 2021-05-12         2017        2021
#
# [2917 rows x 12 columns]

# %%
IRR = (df_irr['latest_market_value']/df_irr['initial_market_value'])**(1/(df_irr['latest_TXY']-df_irr['initial_TXY']))
IRR.agg('mean')
# Out:
# 99.60523193547984

# %% [markdown]
# - Quantity distribution of punk type \
#   98% of punk types are male and female, rare punk tyles are zombie, Ape and Alien.

# %%
punk_types = df2['punk_type'].value_counts()

data1 = go.Bar(x=punk_types.values, y=punk_types.index, orientation='h', text=punk_types.values, textposition='auto')

layout1 = go.Layout(title='Crypto punk type counts',
                    xaxis={'title': 'Quantity'},
                    yaxis={'title': 'Type'},
                   ) #plot_bgcolor='rgba(0,0,0,0) to remove background color

go.Figure(data1, layout1).update_yaxes(categoryorder='total ascending')
# Out:
# <div>                            <div id="a2077bdf-7518-41ea-b357-c0e16cc0d444" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2077bdf-7518-41ea-b357-c0e16cc0d444")) {                    Plotly.newPlot(                        "a2077bdf-7518-41ea-b357-c0e16cc0d444",                        [{"orientation": "h", "text": [6039.0, 3840.0, 88.0, 24.0, 9.0], "textposition": "auto", "type": "bar", "x": [6039, 3840, 88, 24, 9], "y": ["Male", "Female", "Zombie", "Ape", "Alien"]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar ...

# %% [markdown]
# - Average market value per punk type \
#   Pricing premium are given to rare punk types due to its scarcity

# %%
#remove extreme value from latest market value 
df2_noex = df2[(df2['latest_market_value'] < 10000000) & (df2['latest_market_value'] > 0.01)]
df2_noex
# Out:
#       number punk_type initial_owner current_owner transaction_type  \
# 0          0    Female      0xc352b5      0xe08c32    Bid Withdrawn
# 3          3      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 4          4      Male      0xc352b5      0xc352b5    Bid Withdrawn
# 5          5    Female      0xc352b5   WrappedC?€?              Bid
# 6          6      Male      0xc352b5      0xc352b5    Bid Withdrawn
# ...      ...       ...           ...           ...              ...
# 9994    9994    Female           sov      0x69021a              Bid
# 9995    9995    Female   Punkofth?€?      0x758353    Bid Withdrawn
# 9996    9996      Male      0xa9bfa9      0xa9bfa9    Bid Withdrawn
# 9997    9997    Zombie        TJ2010      0x279679          Offered
# 9999    9999    Female      0x7e2d1c   punk9999?€?              Bid
#
#       transaction_frequency  initial_market_value  latest_market_value  \
# 0                        34                 219.0            1030000.0
# 3                        14                  13.0              11638.0
# 4                        11                  28.0             109026.0
# 5                        13                  15.0              11322.0
# 6                         6                  15.0              10126.0
# ...                     ...                   ...                  ...
# 9994                      2                   0.0                527.0
# 9995                      6                  16.0              63960.0
# 9996                      4                  11.0               1338.0
# 9997                     36                  46.0            1480000.0
# 9999                     49                  50.0                960.0
#
#      initial_TXD latest_TXD  initial_TXY  latest_TXY
# 0     2017-06-23 2021-05-10         2017        2021
# 3     2017-06-26 2020-10-04         2017        2020
# 4     2017-06-25 2021-05-13         2017        2021
# 5     2017-06-26 2021-04-29         2017        2021
# 6     2017-06-26 2021-01-04         2017        2021
# ...          ...        ...          ...         ...
# 9994  2021-04-25 2021-04-27         2021        2021
# 9995  2017-06-28 2021-04-20         2017        2021
# 9996  2017-08-04 2021-01-20         2017        2021
# 9997  2017-06-24 2021-05-17         2017        2021
# 9999  2017-06-23 2021-05-12         2017        2021
#
# [5387 rows x 12 columns]

# %%
punk_types_avg = df2_noex.groupby('punk_type')['latest_market_value'].agg('mean').round()

data2 = go.Bar(x=punk_types_avg .values, y=punk_types_avg.index, orientation='h', text=punk_types_avg .values, textposition='auto')

layout2 = go.Layout(title='Average market value per punk type',
                    xaxis={'title': 'Average market value $USD'},
                    yaxis={'title': 'Type'},
                   ) 

go.Figure(data2, layout2).update_yaxes(categoryorder='total ascending')
# Out:
# <div>                            <div id="f24832be-763e-42d5-94f3-2f7ce7e01729" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f24832be-763e-42d5-94f3-2f7ce7e01729")) {                    Plotly.newPlot(                        "f24832be-763e-42d5-94f3-2f7ce7e01729",                        [{"orientation": "h", "text": [2590617.0, 1337208.0, 99650.0, 100876.0, 578270.0], "textposition": "auto", "type": "bar", "x": [2590617.0, 1337208.0, 99650.0, 100876.0, 578270.0], "y": ["Alien", "Ape", "Female", "Male", "Zombie"]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outline ...

# %% [markdown]
# - Pricing distribution of punk type\
#   After price of rare punk types was pumped up, people tend to dig gold in common punk types (male and female)

# %%
#remove extreme value from latest market value and set transaction type as bid
df2_noex = df2[(df2['latest_market_value']<10000000) & (df2['latest_market_value']>0.01) & (df2['transaction_type'] == 'Bid')]

data3 = go.Box(x=df2_noex['punk_type'],
               y=df2_noex['latest_market_value'],
               boxpoints='all')

layout3 = go.Layout(title='Bid - market value distribution of punk type',
                    xaxis={'title':'Type'},
                    yaxis={'title':'Average market value USD$'},
                   ) #plot_bgcolor='rgba(0,0,0,0) to remove background color

go.Figure(data3, layout3)
# Out:
# <div>                            <div id="24a51842-fbba-4e3a-a470-bff3ebba0d01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
, 2923.0, 66.0, 66.0, 11612.0, 62.0, 3.0, 16.0, 1011.0, 175.0, 305.0, 6673.0, 16.0, 89.0, 16.0, 33.0, 53.0, 38626.0, 94.0, 62.0, 612.0, 2758.0, 51.0, 119.0, 66.0, 2.0, 195.0, 11233.0, 1287.0, 527.0, 100.0, 103.0, 13.0, 40364.0, 51.0, 80.0, 13.0, 265.0, 23.0, 612.0, 14.0, 45.0, 13.0, 286.0, 77058.0, 55.0, 211.0, 16.0, 4422.0, 16.0, 2.0, 13.0, 57.0, 72785.0, 23.0, 8986.0, 47.0, 16.0, 21.0, 60.0, 753.0, 51.0, 139.0, 14.0, 83746.0, 13.0, 25577.0, 13.0, 149.0, 45524.0, 124.0, 2.0, 26573.0, 33713.0, 2.0, 2.0, 2.0, 80.0, 105443.0, 239.0, 29.0, 40353.0, 83.0, 16.0, 24.0, 11805 ...

# %% [markdown]
# - Quantity distribution of punk attributes\
#   Punks really love earrings, smokings and colorful lipsticks\
#   Tiara and Beanie are far away from punk style

# %%
punk_attributes = df1['attribute'].value_counts().to_frame()

punk_attributes
# Out:
#                  attribute
# Earring               1900
# Cigarette              739
# Hot Lipstick           547
# Purple Lipstick        492
# Mole                   487
# ...                    ...
# Orange Side             50
# Pilot Helmet            40
# Choker                  37
# Tiara                   37
# Beanie                  30
#
# [87 rows x 1 columns]

# %% [markdown]
# - Punk attributes value map\
#   Price premium is also allocated to rare attribute

# %%
#Scatter chart
punk_att = df[(df['latest_market_value']<10000000)].groupby('attribute')\
                                             .agg({'latest_market_value':['mean', 'count']})

data4 = go.Scatter(y=punk_att['latest_market_value']['mean'],
                   x=punk_att['latest_market_value']['count'],
                   mode='markers',
                   text=punk_att.index)
                   
layout4 = go.Layout(title='Attribute value proposition',
                    xaxis={'title':'Quantity of attribute'},
                    yaxis={'title':'Average market value USD$'})

go.Figure(data4,layout4)
# Out:
# <div>                            <div id="0bd21f0c-246b-481a-b57a-5218744a82a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0bd21f0c-246b-481a-b57a-5218744a82a2")) {                    Plotly.newPlot(                        "0bd21f0c-246b-481a-b57a-5218744a82a2",                        [{"mode": "markers", "text": ["3D Glasses", "Bandana", "Beanie", "Big Beard", "Big Shades", "Black Lipstick", "Blonde Bob", "Blonde Short", "Blue Eye Shadow", "Buck Teeth", "Cap", "Cap Forward", "Chinstrap", "Choker", "Cigarette", "Classic Shades", "Clown Eyes Blue", "Clown Eyes Green", "Clown Hair Green", "Clown Nose", "Cowboy Hat", "Crazy Hair", "Dark Hair", "Do-rag", "Earring", "Eye Mask", "Eye Patch", "Fedora", "Front Beard", "Front Beard Dark", "Frown", "Frumpy Hair", "Goat", "Gold Chain", "Green Eye Shadow", "Half Shaved", "Handlebars", "Headband", "Hoodie", "Horned Rim Glasses", "Hot Lipstick", "Knitted Cap", "Luxurious Beard", "Medical Mask", "Messy Hair", "Mohawk", "Mohawk Dark", "Mohawk Thin", "Mole", "Mustache", "Muttonchops", "Nerd Glasses", "Norm
}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": { ...

# %% [markdown]
# - Crypto punk ownership\
#   Initially, 61% of total crypto punks were controlled by 15 owners. After 4 years, top 15 owners only have 28% of total crypto   punks. Owners capture crypto punk as short-term investment rather than holding it long time.

# %%
punk_own_initial = df2.groupby('initial_owner').agg({'number': 'count'})\
                                               .sort_values(by='number', ascending=False)\
                                               .rename(columns={'number': 'Punk Quantity'}) 

punk_own_initial['percent %'] = punk_own_initial['Punk Quantity'] / 10000 * 100

punk_own_initial['cum_percent %'] = punk_own_initial['Punk Quantity'].cumsum() / 10000 * 100

punk_own_initial.head(15)
# Out:
#                Punk Quantity  percent %  cum_percent %
# initial_owner
# 0xc352b5                1020      10.20          10.20
# 0x00d7c9                1005      10.05          20.25
# Hemba                    919       9.19          29.44
# 0xcbd482                 731       7.31          36.75
# 0x00bd9f                 504       5.04          41.79
# 0x6f4a2d                 319       3.19          44.98
# 0x6611fe                 289       2.89          47.87
# 0xcc7c33                 200       2.00          49.87
# 0xe45df5                 195       1.95          51.82
# 0x48db19                 192       1.92          53.74
# shilpixe?€?              180       1.80          55.54
# 0x26f744                 141       1.41          56.95
# 0x8234be                 140       1.40          58.35
# 0x58164b                 137       1.37          59.72
# 0xba7ccc                 129       1.29          61.01

# %%
punk_own_current = df2.groupby('current_owner').agg({'number': 'count'})\
                                               .sort_values(by='number', ascending=False)\
                                               .rename(columns={'number': 'Punk Quantity'}) 

punk_own_current['percent %'] = punk_own_current['Punk Quantity'] / 10000 * 100

punk_own_current['cum_percent %'] = punk_own_current['Punk Quantity'].cumsum() / 10000 * 100

punk_own_current.head(15)
# Out:
#                Punk Quantity  percent %  cum_percent %
# current_owner
# 0xc352b5                 430       4.30           4.30
# wilcox.e?€?              281       2.81           7.11
# WrappedC?€?              276       2.76           9.87
# 0x577ebc                 269       2.69          12.56
# 0xb88f61                 215       2.15          14.71
# 0x6611fe                 168       1.68          16.39
# 0x6f4a2d                 162       1.62          18.01
# 0xcc7c33                 156       1.56          19.57
# 0x69021a                 147       1.47          21.04
# 0x26f744                 141       1.41          22.45
# 0xcffc33                 127       1.27          23.72
# 0x3be89b                 113       1.13          24.85
# 0x062c54                 111       1.11          25.96
# 0xd79b93                 103       1.03          26.99
# 0x0601d0                 102       1.02          28.01

# %% [markdown]
# - Crypto punk transaction frequency\
#   10% of crypto punk owners have no intention to trade even after 4 years, they treat the pixel image as art for their
#   collections. \
#   Total trading frequency is relatively low due to character of NFT.

# %%
data5 = go.Histogram(x=df2['transaction_frequency'])

layout5 = go.Layout(title='2017-2021 Transaction frequency ',
                    xaxis={'title':'Trading frequency'},
                    yaxis={'title':'Total number'})

go.Figure(data5, layout5)
# Out:
# <div>                            <div id="c329492d-b1f9-4ace-b1ee-bace0581aa06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c329492d-b1f9-4ace-b1ee-bace0581aa06")) {                    Plotly.newPlot(                        "c329492d-b1f9-4ace-b1ee-bace0581aa06",                        [{"type": "histogram", "x": [34, 52, 25, 14, 11, 13, 6, 11, 18, 30, 10, 0, 3, 17, 31, 10, 2, 3, 0, 2, 4, 2, 24, 3, 6, 4, 0, 0, 4, 0, 1, 0, 2, 4, 0, 2, 10, 0, 0, 5, 2, 0, 4, 2, 4, 0, 0, 0, 2, 4, 2, 6, 1, 31, 8, 4, 0, 0, 13, 4, 5, 2, 2, 4, 4, 0, 4,